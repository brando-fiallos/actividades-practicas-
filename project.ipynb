# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
setosa = df[df['species'] == 'setosa']
df['petal_ratio'] = df['petal_length'] / df['petal_width']
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  petal_ratio
# species
# setosa             5.006        3.418         1.464        0.244     7.078000
# versicolor         5.936        2.770         4.260        1.326     3.242837
# virginica          6.588        2.974         5.552        2.026     2.780662

# %%
sepal_lengths = df['sepal_length'].values
print("Media:", np.mean(sepal_lengths))
print("Mediana:", np.median(sepal_lengths))
print("Desviación estándar:", np.std(sepal_lengths))
# Out:
# Media: 5.843333333333334
# Mediana: 5.8
# Desviación estándar: 0.8253012917851409

# %%
plt.hist(df['petal_length'], bins=20, color='lightgreen')
plt.title("Histograma de Longitud del Pétalo")
plt.xlabel("Longitud")
plt.ylabel("Frecuencia")
plt.show()


df['species'].value_counts().plot(kind='bar', color='coral')
plt.title("Cantidad de registros por especie")
plt.xlabel("Especie")
plt.ylabel("Cantidad")
plt.show()


colors = {'setosa':'red', 'versicolor':'blue', 'virginica':'green'}
for specie in df['species'].unique():
    temp = df[df['species'] == specie]
    plt.scatter(temp['sepal_length'], temp['petal_length'], label=specie, color=colors[specie])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Relación entre Sepal y Petal Length")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
axs[0].hist(df['sepal_length'], color='skyblue')
axs[1].hist(df['petal_length'], color='orange')
axs[0].set_title("Longitud del sépalo")
axs[1].set_title("Longitud del pétalo")
plt.tight_layout()
plt.show()

# %%
media = np.mean(df['petal_width'])
mediana = np.median(df['petal_width'])
desviacion = np.std(df['petal_width'])

print("\n--- Estadísticas de petalo ---")
print(f"Media: {media:.2f}")
print(f"Mediana: {mediana:.2f}")
print(f"Desviación estándar: {desviacion:.2f}")
# Out:
# --- Estadísticas de petalo ---
# Media: 1.20
# Mediana: 1.30
# Desviación estándar: 0.76

# %%
plt.figure(figsize=(8, 5))
promedios = df.groupby('species')['sepal_width'].mean()
promedios.plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen'])
plt.title('Promedio de sepalo por especie', fontweight='bold')
plt.xlabel('Especie')
plt.ylabel('Promedio sepalo (cm)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 5))
filtrados = df[df['sepal_length'] > 6.0]
plt.hist(filtrados['petal_length'], bins=12, color='purple', edgecolor='white')
plt.title('Distribución de petalo (sepalo > 6.0 cm)', fontweight='bold')
plt.xlabel('Longitud del pétalo (cm)')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(8, 6))
colores = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}

for especie, grupo in df.groupby('species'):
    plt.scatter(
        grupo['sepal_width'], 
        grupo['petal_width'], 
        color=colores[especie], 
        label=especie,
        alpha=0.7
    )

plt.title('Relación entre sepalo y petalo', fontweight='bold')
plt.xlabel('Ancho del sépalo (cm)')
plt.ylabel('Ancho del pétalo (cm)')
plt.legend()
plt.grid(linestyle='--', alpha=0.3)
plt.show()

# %%
df['petal_ratio'] = df['petal_length'] / df['petal_width']
df.to_csv('iris_modificado.csv', index=False)
print("\n--- Archivo guardado ---")
print("DataFrame guardado como 'iris_modificado.csv'")
# Out:
# --- Archivo guardado ---
# DataFrame guardado como 'iris_modificado.csv'
